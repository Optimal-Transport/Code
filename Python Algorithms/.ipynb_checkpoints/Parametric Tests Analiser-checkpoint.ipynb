# %% [markdown]
# # Results of parametric tests

# %%
import numpy  as np
import pandas as pd
import time
import os
#%matplotlib notebook
import matplotlib.pyplot as plt

# Particular functions
from numpy import zeros, zeros_like, allclose, where, ones, inf, absolute, linspace, tile, maximum, minimum
from numpy.random import default_rng as rng
from numba import jit
from scipy.spatial.distance import cdist
from scipy.linalg import norm

# %% [markdown]
# **Reader**

# %%
folder = 'Microscopy_Sized'
path = 'Exact/' + folder + '/'

# %%
files = [f[:-9] for f in os.listdir(path) if f.endswith('.txt')]
print('There are', len(files), 'instances in this location:')
display(files)
# Out:
# There are 4 instances in this location:
# ['data16_1002-data16_1010_p=S2',
#  'data8_1002-data8_1010_p=S2',
#  'data32_1002-data32_1010_p=S2',
#  'data64_1002-data64_1010_p=S2']

# %%
instance = files[1]
full_path = path + instance

# %%
main_folder = folder + '_Results'
out_folder  = main_folder + '/' + instance
algorithm   = 'PD_Improved'

# %%
#df_collected = pd.read_excel(out_folder+'Critical.xlsx', index_col=0)
df_collected = pd.read_csv(out_folder+'Critical_(τ,σ,ρ,γ).csv.gz', index_col=0)
df_collected.describe()
# Out:
#                   τ             σ             ρ             γ           its  \
# count  1.152000e+06  1.152000e+06  1.152000e+06  1.152000e+06  1.152000e+06
# mean   2.550721e+01  2.550721e+01  1.000000e+00  2.937984e+00  1.246270e+03
# std    3.265553e+01  3.265553e+01  7.071071e-01  1.794470e+00  3.603370e+01
# min    5.917160e-05  5.917160e-05  1.370465e-03  1.000000e-03  4.900000e+01
# 25%    5.437351e-03  5.437351e-03  2.928932e-01  1.350775e+00  1.249000e+03
# 50%    1.213018e+00  1.213018e+00  1.000000e+00  2.900517e+00  1.249000e+03
# 75%    5.050000e+01  5.050000e+01  1.707107e+00  4.450258e+00  1.249000e+03
# max    1.000000e+02  1.000000e+02  1.998630e+00  6.000000e+00  1.249000e+03
#
#            dist_obj          time
# count  1.152000e+06  1.152000e+06
# mean   6.016231e-01  5.005433e-02
# std    4.610440e-01  1.760259e-03
# min    1.651477e-11  2.014160e-03
# 25%    7.957844e-03  4.956174e-02
# 50%    1.000000e+00  5.014563e-02
# 75%    1.000000e+00  5.054235e-02
# ...

# %% [markdown]
# ## ```8x8```

# %% [markdown]
# Observing the relative objective distance to the true objective, we find that many tests reached a distance smaller than the threshold of ```1e-7```:

# %%
plt.figure(figsize = (10,3));    df_collected['dist_obj'].plot(c='orange');    plt.yscale('log');    plt.show()

# %% [markdown]
# If we run
# ```Python
#     int(df_collected[df_collected['dist_obj'] <= 1e-7].describe()['its'].max())
# ```
# we can find that the tests reaching values below the prescribed threshold are actually the tests that finished before the iteration limit.

# %%
plt.figure(figsize = (10,3));    df_collected['its'].plot();    plt.show()

# %% [markdown]
# This allows us to reduce the number of observations substantially.

# %%
df_1249 = df_collected[df_collected['its'] < 1249]
df_1249.describe()
# Out:
#                   τ             σ             ρ             γ           its  \
# count  10748.000000  10748.000000  10748.000000  10748.000000  10748.000000
# mean       0.276623     66.396197      1.505757      1.447393    956.436360
# std        2.417861     24.627000      0.391897      1.202081    233.193214
# min        0.000059      0.012081      0.034074      0.001000     49.000000
# 25%        0.004676     50.000000      1.258819      0.600900    819.000000
# 50%        0.008136     70.000000      1.629320      1.000833   1013.000000
# 75%        0.011859     86.000000      1.838671      2.000667   1145.000000
# max       58.000000    100.000000      1.998630      6.000000   1248.000000
#
#            dist_obj          time
# count  1.074800e+04  10748.000000
# mean   4.991783e-08      0.038576
# std    2.901647e-08      0.009415
# min    1.651477e-11      0.002014
# 25%    2.446494e-08      0.033072
# 50%    5.030915e-08      0.040755
# 75%    7.508957e-08      0.046169
# ...

# %% [markdown]
# Running
# ```Python
#     int(df_1249.drop_duplicates(subset=['τ','σ']).describe().iloc[0,0])
# ```
# We can further observe that there are 633 pairs of values $(\tau,\sigma) \in \Theta_2$ for which more than one value of $\rho$ resulted in a _successful_ test.
#
# Similarly, if we run the following line, we will get that there are 5288 triplets of $(\tau,\sigma,\rho)$ for which more than a value of $\gamma$ resulted in a _successful_ test.
# ```Python
#     int(df_1249[df_1249.duplicated(subset=['τ','σ','ρ'])].describe().iloc[0,0])
# ```

# %% [markdown]
# Let us start by plotting density plots for each parameter. We observe that most successful tests have a small value of $\tau$. There is a significant concentration around $[0.005,0.01]$. In terms of $\sigma$, we can observe that high values may yield good results, with a plot similar to a linear function. We will take special care on $ \sigma \geq 70$. The inertia parameter also gives better results the larger it is, here the histogram mimics exponential growth. We will focus on $\rho > 1.75$. Finally, the scaling parameter concentrates most of its best results around the value of one, however, smaller values seem to be competitive. We will study $\gamma \leq 1$.

# %%
import seaborn as sns

# %%
# Density plots for each parameter
plt.figure(figsize = (20,10))

plt.subplot(2, 4, 1)
sns.kdeplot(df_1249['τ'], bw_method=0.2, shade=True)

plt.subplot(2, 4, 2)
g2 = sns.kdeplot(df_1249['σ'], bw_method=0.1, shade=True)
g2.set(ylabel=None)

plt.subplot(2, 4, 3)
g2 = sns.kdeplot(df_1249['ρ'], bw_method=0.15, shade=True)
g2.set(ylabel=None)

plt.subplot(2, 4, 4)
g2 = sns.kdeplot(df_1249['γ'], bw_method=0.15, shade=True)
g2.set(ylabel=None)

# Second row
plt.subplot(2, 4, 5)
g2 = sns.kdeplot(df_1249['τ'][df_1249['τ']<0.015], bw_method=0.1, shade=True)
g2.ticklabel_format(axis='x',style='sci',scilimits=(1,3))

plt.subplot(2, 4, 6)
g2 = sns.kdeplot(df_1249['σ'][df_1249['σ']>70], bw_method=0.1, shade=True)
g2.set(ylabel=None)

plt.subplot(2, 4, 7)
g2 = sns.kdeplot(df_1249['ρ'][df_1249['ρ']>1.6], shade=True)
g2.set(ylabel=None)

plt.subplot(2, 4, 8)
g2 = sns.kdeplot(df_1249['γ'][df_1249['γ']<=1.25], bw_method=0.15, shade=True)
g2.set(ylabel=None)



plt.plot();

# %% [markdown]
# We can see that the concentrations described above are also related to each other. to see this, let us plot $\tau$ against each parameter and consider a zoom around $[0.005,0.01]$.

# %%
df_1249_τ = df_1249[df_1249['τ'].between(5e-3, 0.01, inclusive='both')]
df_1249_τ.describe()
# Out:
#                  τ            σ            ρ            γ          its  \
# count  4006.000000  4006.000000  4006.000000  4006.000000  4006.000000
# mean      0.007635    77.277084     1.495566     1.566401   966.594358
# std       0.001415    18.310094     0.386963     1.194570   227.019560
# min       0.005072     6.000000     0.161329     0.200967    49.000000
# 25%       0.006432    66.000000     1.258819     0.600900   829.000000
# 50%       0.007630    82.000000     1.544639     1.200800  1022.000000
# 75%       0.008876    92.000000     1.838671     2.200633  1148.000000
# max       0.009985   100.000000     1.998630     6.000000  1248.000000
#
#            dist_obj         time
# count  4.006000e+03  4006.000000
# mean   4.987401e-08     0.039005
# std    2.888629e-08     0.009177
# min    2.277354e-11     0.002014
# 25%    2.479952e-08     0.033450
# 50%    5.000256e-08     0.041139
# 75%    7.493637e-08     0.046385
# max    9.998417e-08     0.053855

# %%
# Visualise grids
plt.figure(figsize = (15,15))

plt.subplot(3, 3, 1)
plt.title(r'Points of of $\Theta_1$ in subdataset')
plt.plot(df_1249['τ'],df_1249['σ'],'x',color='red',alpha=0.3)
plt.hexbin(df_1249['τ'], df_1249['σ'], gridsize=25, cmap='Reds',mincnt=1)
plt.xlabel('');    plt.ylabel('σ');

plt.subplot(3, 3, 2)
plt.title(r'Points of of $\Pi_1(\Theta_1) \times \Theta_2$ in subdataset')
plt.plot(df_1249['τ'], df_1249['ρ'],'x', color='black', alpha=0.3)
plt.xlabel('');    plt.ylabel('ρ');
plt.hexbin(df_1249['τ'], df_1249['ρ'], gridsize=25, cmap='Blues',mincnt=1)

plt.subplot(3, 3, 3)
plt.title(r'Points of of $\Pi_1(\Theta_1) \times \Theta_3$ in subdataset')
plt.plot(df_1249['τ'], df_1249['γ'],'x', color='black', alpha=0.3)
plt.xlabel('');    plt.ylabel('γ');
plt.hexbin(df_1249['τ'], df_1249['γ'], gridsize=25, cmap='Purples',mincnt=1)

# Zoom in!
plt.subplot(3, 3, 4)
plt.plot(df_1249_τ['τ'],df_1249_τ['σ'],'x',color='red',alpha=0.05)
plt.hexbin(df_1249_τ['τ'], df_1249_τ['σ'], gridsize=25, cmap='Reds',mincnt=1)
plt.xlabel('τ');    plt.ylabel('σ');

plt.subplot(3, 3, 5)
plt.plot(df_1249_τ['τ'], df_1249_τ['ρ'],'x',color='black',alpha=0.05)
plt.hexbin(df_1249_τ['τ'], df_1249_τ['ρ'], gridsize=25, cmap='Blues',mincnt=1)
plt.xlabel('τ');    plt.ylabel('ρ');

plt.subplot(3, 3, 6)
plt.plot(df_1249_τ['τ'], df_1249_τ['γ'], 'x', color='purple', alpha=0.05)
plt.hexbin(df_1249_τ['τ'], df_1249_τ['γ'], gridsize=25, cmap='Purples',mincnt=1)
plt.xlabel('τ');    plt.ylabel('γ');


plt.show()

# %% [markdown]
# Let us now zoom into the aforementioned ranges for the other parameters:

# %%
df_1249_τρ = df_1249_τ[df_1249_τ['ρ'].between(1.75, 2.0, inclusive='both')]
df_1249_τρ.describe()
# Out:
#                  τ            σ            ρ            γ          its  \
# count  1310.000000  1310.000000  1310.000000  1310.000000  1310.000000
# mean      0.007651    76.761832     1.881580     1.779452   936.417557
# std       0.001435    18.369680     0.074598     1.389436   241.658818
# min       0.005072     6.000000     1.777146     0.200967    49.000000
# 25%       0.006432    68.000000     1.838671     0.600900   780.250000
# 50%       0.007782    80.000000     1.891007     1.400767   990.000000
# 75%       0.008876    92.000000     1.933580     2.600567  1136.000000
# max       0.009985   100.000000     1.998630     6.000000  1248.000000
#
#            dist_obj         time
# count  1.310000e+03  1310.000000
# mean   4.988789e-08     0.037791
# std    2.882961e-08     0.009768
# min    1.026550e-10     0.002014
# 25%    2.497556e-08     0.031661
# 50%    5.076323e-08     0.040071
# 75%    7.481854e-08     0.045780
# max    9.998417e-08     0.052861

# %%
def visualise_params(df):
    # Visualise grids
    plt.figure(figsize = (15,5))

    plt.subplot(1, 3, 1)
    plt.title(r'Points of of $\Theta_1$ in subdataset')
    plt.plot(df['τ'], df['σ'],'x',color='red',alpha=0.3)
    plt.hexbin(df['τ'], df['σ'], gridsize=25, cmap='Reds',mincnt=1)
    plt.xlabel('τ');    plt.ylabel('σ');

    plt.subplot(1, 3, 2)
    plt.title(r'Points of of $\Pi_1(\Theta_1) \times \Theta_2$ in subdataset')
    plt.plot(df['τ'], df['ρ'],'x', color='black', alpha=0.01)
    plt.xlabel('τ');    plt.ylabel('ρ');
    plt.hexbin(df['τ'], df['ρ'], gridsize=25, cmap='Blues',mincnt=1)

    plt.subplot(1, 3, 3)
    plt.title(r'Points of of $\Pi_1(\Theta_1) \times \Theta_3$ in subdataset')
    plt.plot(df['τ'], df['γ'],'x', color='black', alpha=0.01)
    plt.xlabel('τ');    plt.ylabel('γ');
    plt.hexbin(df['τ'], df['γ'], gridsize=25, cmap='Purples',mincnt=1)
    plt.plot();

# %%
visualise_params(df_1249_τρ)

# %%
df_1249_τσρ = df_1249_τρ[df_1249_τρ['σ'].between(70.0, 100.0, inclusive='both')]
df_1249_τσρ.describe()
# Out:
#                 τ           σ           ρ           γ          its  \
# count  950.000000  950.000000  950.000000  950.000000   950.000000
# mean     0.007638   86.044211    1.878326    1.933073   935.262105
# std      0.001429    9.047477    0.074759    1.434652   235.795507
# min      0.005099   70.000000    1.777146    0.200967    49.000000
# 25%      0.006432   78.000000    1.838671    0.600900   788.500000
# 50%      0.007782   88.000000    1.891007    1.600733   987.500000
# 75%      0.008876   94.000000    1.933580    3.000500  1122.000000
# max      0.009944  100.000000    1.998630    6.000000  1248.000000
#
#            dist_obj        time
# count  9.500000e+02  950.000000
# mean   4.914019e-08    0.037765
# std    2.868675e-08    0.009532
# min    1.026550e-10    0.002014
# 25%    2.377811e-08    0.031823
# 50%    5.023754e-08    0.040015
# 75%    7.383324e-08    0.045334
# max    9.990557e-08    0.052861

# %%
visualise_params(df_1249_τσρ)

# %%
df_1249_τσργ = df_1249_τσρ[df_1249_τσρ['γ'].between(0.0, 1.0, inclusive='both')]
df_1249_τσργ.describe()
# Out:
#                 τ           σ           ρ           γ          its  \
# count  323.000000  323.000000  323.000000  323.000000   323.000000
# mean     0.007520   85.857585    1.883208    0.485672   894.024768
# std      0.001437    9.096694    0.072283    0.256607   263.890269
# min      0.005099   70.000000    1.777146    0.200967    49.000000
# 25%      0.006295   78.000000    1.838671    0.200967   689.500000
# 50%      0.007458   86.000000    1.891007    0.400933   972.000000
# 75%      0.008731   94.000000    1.933580    0.600900  1092.500000
# max      0.009944  100.000000    1.998630    1.000000  1248.000000
#
#            dist_obj        time
# count  3.230000e+02  323.000000
# mean   5.195182e-08    0.036053
# std    2.910078e-08    0.010620
# min    1.026550e-10    0.002014
# 25%    2.805150e-08    0.028172
# 50%    5.570303e-08    0.038922
# 75%    7.801194e-08    0.044587
# max    9.990557e-08    0.051013

# %%
visualise_params(df_1249_τσργ)

# %% [markdown]
# We can still see, though, that there are many points for which the number of iterations is high. Let's see if there are any patters for which the number of iterations is below, say, 600 iterations.

# %%
plt.figure(figsize = (10,3));    plt.plot(df_1249_τσργ.its.values,'x',color='orange');    plt.show()

# %%
df_1249_τσργi = df_1249_τσργ[df_1249_τσργ.its.between(0, 600, inclusive='both')]
df_1249_τσργi.describe()
# Out:
#                τ           σ          ρ          γ         its      dist_obj  \
# count  54.000000   54.000000  54.000000  54.000000   54.000000  5.400000e+01
# mean    0.007876   84.740741   1.875580   0.500824  445.425926  4.833839e-08
# std     0.001462    9.383215   0.066430   0.271046  137.588476  2.769250e-08
# min     0.005099   70.000000   1.777146   0.200967   49.000000  2.966407e-10
# 25%     0.006855   76.000000   1.838671   0.200967  375.500000  2.533389e-08
# 50%     0.007871   86.000000   1.891007   0.400933  481.500000  4.902572e-08
# 75%     0.009179   94.000000   1.933580   0.750875  544.500000  7.076236e-08
# max     0.009944  100.000000   1.998630   1.000000  600.000000  9.490017e-08
#
#             time
# count  54.000000
# mean    0.018068
# std     0.005711
# min     0.002014
# 25%     0.015123
# 50%     0.019586
# 75%     0.022037
# max     0.028618

# %%
visualise_params(df_1249_τσργi)

# %% [markdown]
# Let us now check where is the minimal value of iterations:

# %%
df_1249[df_1249['its'] <= 50]
# Out:
#                τ     σ         ρ         γ  its      dist_obj      time
# 284097  0.009944  72.0  1.987688  0.200967   49  6.189456e-08  0.002014

# %% [markdown]
# From the plots above, we can see that the best results come from a particular choice of parameters that lies in the region we have been displaying. However, there is no concentration of values around this plot for $\gamma$.

# %%
df_1249_τᵣσρ = df_1249_τσρ[df_1249_τσρ['τ']>0.009]

# %%
visualise_params(df_1249_τᵣσρ)

# %%
df_1249[df_1249['dist_obj'] <= 1e-10]
# Out:
#                 τ     σ         ρ         γ   its      dist_obj      time
# 153326   0.007048  68.0  1.629320  2.600567   896  9.379235e-11  0.036339
# 186093   0.002550  58.0  1.891007  2.400600   944  9.002589e-11  0.037292
# 537122   0.025571  28.0  1.052336  0.400933  1172  1.651477e-11  0.047585
# 600579   0.012863  46.0  1.358368  0.600900   543  6.078161e-11  0.022087
# 648841   0.001065  50.0  1.933580  1.600733   839  4.180613e-11  0.034227
# 678310   0.016386  52.0  1.258819  1.000833  1231  2.460893e-11  0.049723
# 870114   0.006164  96.0  0.641632  0.400933   997  2.277354e-11  0.039673
# 961451   0.011548  62.0  1.052336  2.000667  1064  4.903015e-11  0.043160
# 1023809  0.007013  54.0  0.947664  0.200967  1109  2.427116e-11  0.044441
# 1131781  0.002367  90.0  1.987688  1.000000   932  6.470082e-11  0.037877

# %%
plt.plot(df_1249_τσργ['τ'],
         df_1249_τσργ['σ']*df_1249_τσργ['τ'],'x',color='red',alpha=0.01)
plt.hexbin(df_1249_τσργ['τ'], 
           df_1249_τσργ['σ']*df_1249_τσργ['τ'], gridsize=25, cmap='Reds',mincnt=1)

# %%
plt.figure(figsize = (8,3))

plt.title(r'Relative distance w.r.t. (τ,σ)')
sc = plt.scatter(df_1249_τσργi['τ'],df_1249_τσργi['σ'], marker='*', c=df_1249_τσργi['its'])
plt.colorbar(sc,fraction=0.02, pad=0.1,label='Iteration count')
plt.xlabel('τ');    plt.ylabel('σ');

plt.show()

# %%
plt.figure(figsize = (8,3))

plt.title(r'Relative distance w.r.t. (τ,σ)')
sc = plt.scatter(df_1249_τσργi['τ']*df_1249_τσργi['σ'], df_1249_τσργi['its'], marker='*',color='black',alpha=0.3)
#plt.hexbin(A['τ']*A['σ'], A['its'], gridsize=25, cmap='Reds',mincnt=1)
plt.xlabel('στ');    plt.ylabel('Iterations');

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ```Python
# # Plot each parameter and resulting distance (coloured)
# fig = plt.figure(figsize = (10,8))
# ax = fig.add_subplot(projection='3d')
#
# sc = ax.scatter(df_1999['τ'], df_1999['σ'], df_1999['ρ'], marker='^', c=df_1999['dist_obj'])
#
# ax.set_xlabel('τ')
# ax.set_ylabel('σ')
# ax.set_zlabel('ρ')
# plt.colorbar(sc,fraction=0.02, pad=0.2,label='Relative distance')
#
# plt.show()
# ```
